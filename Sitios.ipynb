# %%
import pandas as pd
import json

# %%
import json
import pandas as pd

def abrir_json_y_crear_pandas(ruta_archivo):
    data = []
    with open(ruta_archivo, 'r') as archivo:
        for linea in archivo:
            try:
                objeto = json.loads(linea)
                data.append(objeto)
            except json.JSONDecodeError as e:
                print(f"Error al cargar el JSON en la línea {e.lineno}: {e.msg}")

    df = pd.DataFrame(data)

# %%
a=abrir_json_y_crear_pandas('6.json',"df.csv")

# %%
b=pd.read_csv("df.csv")

# %%
b
# Out:
#                                            name  \
# 0                               Porter Pharmacy
# 1                                 Bahama Dawn's
# 2                         Cudd Pressure Control
# 3                     Eighty Niner Dry Cleaners
# 4       Riverside Autoplex of McAlester - Honda
# ...                                         ...
# 274996            Queen City Optical Provisions
# 274997                    L & S Auto Repair Inc
# 274998                  Denver Pet Sitters Inc.
# 274999           Summit Security Services, Inc.
# 275000                              Lane Bryant
#
#                                                   address  \
# 0       Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       Bahama Dawn's, 1724 E Carl Albert Pkwy, McAles...
# 2       Cudd Pressure Control, 405 E Highway 270 # A, ...
# 3       Eighty Niner Dry Cleaners, 115 S 6th St, McAle...
# 4       Riverside Autoplex of McAlester - Honda, 918 S...
# ...

# %%
import json

with open('6.json', 'r') as f:
    try:
        data = json.load(f)
        print("El archivo JSON está bien formateado.")
    except json.JSONDecodeError as e:
        print("Error al cargar el archivo JSON:", e.msg)
        print("En la línea", e.lineno, "columna", e.colno)
# Out:
# Error al cargar el archivo JSON: Extra data
# En la línea 2 columna 1

# %%
f
# Out:
# <_io.TextIOWrapper name='6.json' mode='r' encoding='cp1252'>
